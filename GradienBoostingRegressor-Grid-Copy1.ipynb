# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
depn=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV    # use GridSearchCrossValidation lib
from sklearn.ensemble import GradientBoostingRegressor   # lib for DTR                         
param_grid={'n_estimators':[10,100],
            'criterion':['mse','friedman_mse'],
            'loss':['mse','mae','huber','quantile'],
            'max_features':['sqrt','log2']}  #plable parametter for hyper tunning
grid=GridSearchCV(GradientBoostingRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)  #import(lib),True for find good model,
grid.fit(indep,depn)  #fitting the model for grid
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/ensemble/_gb.py:672: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/ensemble/_gb.py:672: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/ensemble/_gb.py:672: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?
# ...

# %%
re=grid.cv_results_
print("The R_score value for best parameter{}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter{'criterion': 'friedman_mse', 'loss': 'huber', 'max_features': 'log2', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.000608      0.000213         0.000000        0.000000
# 1        0.000601      0.000118         0.000000        0.000000
# 2        0.000520      0.000110         0.000000        0.000000
# 3        0.000514      0.000012         0.000000        0.000000
# 4        0.000473      0.000039         0.000000        0.000000
# 5        0.000460      0.000030         0.000000        0.000000
# 6        0.000396      0.000091         0.000000        0.000000
# 7        0.000383      0.000105         0.000000        0.000000
# 8        0.000420      0.000095         0.000000        0.000000
# 9        0.000244      0.000022         0.000000        0.000000
# 10       0.000169      0.000031         0.000000        0.000000
# 11       0.000186      0.000050         0.000000        0.000000
# 12       0.000192      0.000045         0.000000        0.000000
# ...

# %%
age_input=int(input("Age:"))
Bmi_input=float(input("BMI"))
Childran_input=int(input("NO childran"))
sex_male_input=int(input("sex Male 0 or 1:"))
smoker_yes_input=int(input("smoker Yes 0 or 1:"))
# Out:
# Age: 25
# BMI 55
# NO childran 2
# sex Male 0 or 1: 0
# smoker Yes 0 or 1: 1

# %%
Future_prediction=grid.predict([[age_input,Bmi_input,Childran_input,sex_male_input,smoker_yes_input]])
print("Future_prediction",Future_prediction)
# Out:
# Future_prediction [40079.7189631]
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
